# %%
b <- c(1,2,3,4)

# %%
mean(b)
# Out:
# [1] 2.5

# %%
var(b)
# Out:
# [1] 1.666667

# %%
my_mean <- function(value_list){
    x <- 0
    for (i in 1:length(value_list))
        {
        x <- x + value_list[i]
    }
    return ( x/length(value_list))
}

# %%
my_mean(c(1,2,3,4))
# Out:
# [1] 2.5

# %%
methods(plot)
# Out:
#  [1] plot.acf*           plot.data.frame*    plot.decomposed.ts*
#  [4] plot.default        plot.dendrogram*    plot.density*
#  [7] plot.ecdf           plot.factor*        plot.formula*
# [10] plot.function       plot.hclust*        plot.histogram*
# [13] plot.HoltWinters*   plot.isoreg*        plot.lm*
# [16] plot.medpolish*     plot.mlm*           plot.ppr*
# [19] plot.prcomp*        plot.princomp*      plot.profile.nls*
# [22] plot.raster*        plot.spec*          plot.stepfun
# [25] plot.stl*           plot.table*         plot.ts
# [28] plot.tskernel*      plot.TukeyHSD*
# see '?methods' for accessing help and source code

# %%
plot(density(rnorm(20, mean=5, sd=1)), ylim=c(0,0.5), xlim=c(1,9))
curve(dnorm(x, mean = 5, sd =1 ), add=TRUE, col='red')
# Out:
# Plot with title "density.default(x = rnorm(20, mean = 5, sd = 1))"

# %%
plot(density(rchisq(100, 7)), ylim=c(0,0.2))
curve(dchisq(x, df = 7 ), from = 0, to = 25, add=TRUE, col='red')
# Out:
# Plot with title "density.default(x = rchisq(100, 7))"

# %%
x <- c()
for (i in 1:1000) {
    x <- c(x, mean(rchisq(100,7)))
}
plot(density(x))
curve(dnorm(x, mean=7, sd=.35), add=TRUE, col='red')
# Out:
# Plot with title "density.default(x = x)"

# %%
x <- seq(1,10)
y <- seq(11,20)
plot(x,y)
# Out:
# plot without title

# %%
install.packages("ISLR")
# Out:
# package 'ISLR' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\hewas\AppData\Local\Temp\Rtmp0sbhhK\downloaded_packages

# %%
library(ISLR)
# Out:
# Warning message:
# "package 'ISLR' was built under R version 3.6.3"

# %%
library(dplyr)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 3.6.3"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
glimpse(Wage)
# Out:
# Rows: 3,000
# Columns: 11
# $ year       <int> 2006, 2004, 2003, 2003, 2005, 2008, 2009, 2008, 2006, 20...
# $ age        <int> 18, 24, 45, 43, 50, 54, 44, 30, 41, 52, 45, 34, 35, 39, ...
# $ maritl     <fct> 1. Never Married, 1. Never Married, 2. Married, 2. Marri...
# $ race       <fct> 1. White, 1. White, 1. White, 3. Asian, 1. White, 1. Whi...
# $ education  <fct> 1. < HS Grad, 4. College Grad, 3. Some College, 4. Colle...
# $ region     <fct> 2. Middle Atlantic, 2. Middle Atlantic, 2. Middle Atlant...
# $ jobclass   <fct> 1. Industrial, 2. Information, 1. Industrial, 2. Informa...
# $ health     <fct> 1. <=Good, 2. >=Very Good, 1. <=Good, 2. >=Very Good, 1....
# $ health_ins <fct> 2. No, 2. No, 1. Yes, 1. Yes, 1. Yes, 1. Yes, 1. Yes, 1....
# $ logwage    <dbl> 4.318063, 4.255273, 4.875061, 5.041393, 4.318063, 4.8450...
# $ wage       <dbl> 75.04315, 70.47602, 130.98218, 154.68529, 75.04315, 127....

# %%
names(Wage)
# Out:
#  [1] "year"       "age"        "maritl"     "race"       "education"
#  [6] "region"     "jobclass"   "health"     "health_ins" "logwage"
# [11] "wage"

# %%
is.data.frame(Wage)
# Out:
# [1] TRUE

# %%
Wage$race
# Out:
#    [1] 1. White 1. White 1. White 3. Asian 1. White 1. White 4. Other 3. Asian
#    [9] 2. Black 1. White 1. White 1. White 1. White 1. White 1. White 1. White
#   [17] 3. Asian 1. White 1. White 1. White 3. Asian 1. White 1. White 1. White
#   [25] 1. White 1. White 1. White 4. Other 1. White 2. Black 1. White 1. White
#   [33] 1. White 1. White 1. White 1. White 1. White 1. White 1. White 1. White
#   [41] 3. Asian 1. White 1. White 4. Other 2. Black 1. White 1. White 1. White
#   [49] 1. White 1. White 1. White 1. White 1. White 1. White 1. White 2. Black
#   [57] 1. White 3. Asian 1. White 1. White 1. White 1. White 1. White 1. White
#   [65] 1. White 1. White 1. White 1. White 3. Asian 2. Black 1. White 1. White
#   [73] 1. White 1. White 2. Black 1. White 1. White 1. White 1. White 1. White
#   [81] 3. Asian 1. White 1. White 1. White 1. White 1. White 1. White 1. White
#   [89] 1. White 3. Asian 1. White 1. White 1. White 1. White 1. White 1. White
# ...

# %%
x <- Wage[['year']]
y <- Wage[['wage']]
print(x)
# Out:
#    [1] 2006 2004 2003 2003 2005 2008 2009 2008 2006 2004 2007 2007 2005 2003
#   [15] 2009 2009 2003 2006 2007 2003 2003 2005 2009 2007 2006 2005 2006 2004
#   [29] 2008 2003 2004 2005 2008 2005 2006 2003 2006 2004 2006 2003 2004 2007
#   [43] 2004 2005 2004 2008 2009 2007 2006 2006 2005 2008 2004 2003 2009 2004
#   [57] 2006 2003 2004 2003 2005 2006 2005 2004 2003 2003 2009 2003 2004 2008
#   [71] 2004 2006 2006 2006 2009 2003 2003 2006 2003 2008 2005 2004 2009 2003
#   [85] 2007 2006 2004 2009 2009 2009 2004 2003 2003 2005 2006 2009 2003 2006
#   [99] 2009 2005 2009 2008 2004 2005 2008 2006 2007 2003 2007 2006 2009 2008
#  [113] 2004 2006 2003 2007 2009 2006 2008 2005 2006 2009 2006 2008 2009 2005
#  [127] 2004 2004 2009 2003 2007 2008 2007 2008 2005 2004 2009 2007 2004 2003
#  [141] 2004 2006 2003 2007 2005 2004 2005 2004 2007 2004 2007 2008 2003 2003
#  [155] 2003 2008 2005 2004 2003 2005 2007 2008 2008 2007 2003 2007 2003 2004
# ...

# %%
print((y))
# Out:
#    [1]  75.04315  70.47602 130.98218 154.68529  75.04315 127.11574 169.52854
#    [8] 111.72085 118.88436 128.68049 117.14682  81.28325  89.49248 134.70538
#   [15] 134.70538  90.48191  82.67964 212.84235 129.15669  98.59934 200.54326
#   [22]  50.40666  85.38394 160.64248  94.07271 277.60142  84.04596  65.11085
#   [29] 116.26532  70.47602 195.67631 101.40205  81.28325 111.72085  89.88005
#   [36]  87.98103  87.98103 103.90247 105.92781  66.22941  34.60742 109.83399
#   [43]  45.28217  73.77574  81.28325 154.68529 267.90109 176.98965  66.22941
#   [50] 116.26532 200.54326 101.82435 272.29478  35.03342 114.47571  81.28325
#   [57] 200.54326 148.41316  99.68946 111.72085 152.83880 117.14682  77.73760
#   [64]  87.98103 125.52550 123.33610 158.29462 200.54326  99.68946  70.47602
#   [71]  94.07271  81.28325  81.28325 100.76427  94.07271  99.68946 268.26629
#   [78]  81.28325 113.56709  87.98103 128.68049 106.72398  66.04469  51.52196
# ...

# %%
plot(x,y, xlab='year', ylab='wage')
# Out:
# plot without title

# %%
age = Wage[['age']]
wage = Wage[['wage']]

# %%
plot(age, wage, xlab='age', ylab='wage')
# Out:
# plot without title

# %%
boxplot(Wage$wage - Wage$year, col=rainbow(5))
boxplot(Wage$wage - Wage$education, col=rainbow(5), ylab = 'wages', xlab = 'education')
# Out:
# Warning message in Ops.factor(Wage$wage, Wage$education):
# "'-' not meaningful for factors"Warning message in min(x):
# "min에 전달되는 인자들 중 누락이 있어 Inf를 반환합니다"Warning message in max(x):
# "max에 전달되는 인자들 중 누락이 있어 -Inf를 반환합니다"
# Error in plot.window(xlim = xlim, ylim = ylim, log = log, yaxs = pars$yaxs): 유한한 값들만이 'ylim'에 사용될 수 있습니다
# Traceback:
#
# 1. boxplot(Wage$wage - Wage$education, col = rainbow(5), ylab = "wages",
#  .     xlab = "education")
# 2. boxplot.default(Wage$wage - Wage$education, col = rainbow(5),
#  .     ylab = "wages", xlab = "education")
# 3. do.call("bxp", c(list(z, notch = notch, width = width, varwidth = varwidth,
#  .     log = log, border = border, pars = pars, outline = outline,
#  .     horizontal = horizontal, add = add, ann = ann, at = at),
#  .     args[namedargs]))
# 4. bxp(list(stats = structure(c(NA_real_, NA_real_, NA_real_, NA_real_,
#  . NA_real_), .Dim = c(5L, 1L), class = structure("logical", .Names = "")),
# ...

# %%
Wage
# Out:
#        year age maritl           race     education          region
# 231655 2006 18  1. Never Married 1. White 1. < HS Grad       2. Middle Atlantic
# 86582  2004 24  1. Never Married 1. White 4. College Grad    2. Middle Atlantic
# 161300 2003 45  2. Married       1. White 3. Some College    2. Middle Atlantic
# 155159 2003 43  2. Married       3. Asian 4. College Grad    2. Middle Atlantic
# 11443  2005 50  4. Divorced      1. White 2. HS Grad         2. Middle Atlantic
# 376662 2008 54  2. Married       1. White 4. College Grad    2. Middle Atlantic
# 450601 2009 44  2. Married       4. Other 3. Some College    2. Middle Atlantic
# 377954 2008 30  1. Never Married 3. Asian 3. Some College    2. Middle Atlantic
# 228963 2006 41  1. Never Married 2. Black 3. Some College    2. Middle Atlantic
# 81404  2004 52  2. Married       1. White 2. HS Grad         2. Middle Atlantic
# 302778 2007 45  4. Divorced      1. White 3. Some College    2. Middle Atlantic
# ...

# %%
Wage$education
# Out:
#    [1] 1. < HS Grad       4. College Grad    3. Some College
#    [4] 4. College Grad    2. HS Grad         4. College Grad
#    [7] 3. Some College    3. Some College    3. Some College
#   [10] 2. HS Grad         3. Some College    2. HS Grad
#   [13] 2. HS Grad         4. College Grad    2. HS Grad
#   [16] 3. Some College    4. College Grad    5. Advanced Degree
#   [19] 4. College Grad    3. Some College    4. College Grad
#   [22] 2. HS Grad         4. College Grad    4. College Grad
#   [25] 2. HS Grad         5. Advanced Degree 2. HS Grad
#   [28] 2. HS Grad         2. HS Grad         2. HS Grad
#   [31] 5. Advanced Degree 3. Some College    5. Advanced Degree
#   [34] 2. HS Grad         4. College Grad    5. Advanced Degree
#   [37] 4. College Grad    4. College Grad    3. Some College
#   [40] 1. < HS Grad       4. College Grad    4. College Grad
#   [43] 1. < HS Grad       1. < HS Grad       2. HS Grad
#   [46] 5. Advanced Degree 4. College Grad    5. Advanced Degree
# ...
